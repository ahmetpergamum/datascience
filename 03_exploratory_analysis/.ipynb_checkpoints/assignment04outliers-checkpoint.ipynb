# %% [markdown]
# # Keşifsel Veri Analizi
#
# ## Aykırı Değerler

# %% [markdown]
# Bu ödevde ABD Eğitim Sistemi'ne ait verileri inceleyemeye devam edeceksiniz. Bu veri kümesinde eyalet bazında yıllık bir çok veri bulunmaktadır. Bu verilerin açıklamalarına yine Kaggle'dan ulaşabilirsiniz.
#
# Öncelikle bir önceki derste uyguladağınız eksik değerleri tamamlama tekniklerinden en uygun olanını uygulayın. Aşağıdaki sorulara cevap verebilmeniz için eksik verilerin üstesinden gelmelisiniz.
#
# ### Q1
# Toplam gelir verilerini içeren TOTAL_REVENUE ve toplam harcama verilerini içeren TOTAL_EXPENDITURE değişkenlerini inceleyin. Bu değişkenler aykırı değerler içeriyor mu?

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('states_all.csv')

#plt.boxplot(df['TOTAL_REVENUE'], whis=20)
plt.hist(df['TOTAL_REVENUE'], bins = 1000)

plt.show()

df.groupby('STATE').mean()
# Out:
#                  YEAR        ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# STATE
# ALABAMA        2001.5  7.365843e+05     5545854.92        603748.88
# ALASKA         2001.5  1.304296e+05     1720039.64        251586.32
# ARIZONA        2001.5  8.743221e+05     6577442.12        786517.80
# ARKANSAS       2001.5  4.519019e+05     3611403.96        407411.80
# CALIFORNIA     2001.5  5.945343e+06    55799199.28       5788586.00
# ...               ...           ...            ...              ...
# WASHINGTON     2001.5  1.010687e+06     9295918.12        752469.48
# WEST VIRGINIA  2001.5           NaN            NaN              NaN
# WEST_VIRGINIA  2004.5  2.891283e+05     2664419.00        287330.80
# WISCONSIN      2001.5  8.671074e+05     8944846.84        572206.44
# WYOMING        2001.5  9.166442e+04     1173952.68         86561.00
#
#                STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# STATE
# ALABAMA           3188192.24     1753913.80         5690278.88
# ALASKA            1069718.48      398734.84         1817666.40
# ARIZONA           2771293.36     3019630.96         6549709.12
# ARKANSAS          2603627.80      600364.36         3707725.96
# CALIFORNIA       30969284.28    19041329.00        56247851.32
# ...                      ...            ...                ...
# WASHINGTON        5764736.68     2778711.96         9481863.84
# WEST VIRGINIA            NaN            NaN                NaN
# WEST_VIRGINIA     1564013.72      813074.48         2670432.28
# WISCONSIN         4404704.20     3967936.20         8995488.76
# WYOMING            611459.16      475932.52         1152672.48
#
#                INSTRUCTION_EXPENDITURE  SUPPORT_SERVICES_EXPENDITURE  \
# STATE
# ALABAMA                     2937209.32                    1673645.84
# ALASKA                       892252.12                     630044.56
# ARIZONA                     3024480.36                    2073114.92
# ARKANSAS                    1887682.80                    1121556.84
# CALIFORNIA                 27882975.88                   16237200.96
# ...                                ...                           ...
# WASHINGTON                  4624236.92                    2809570.56
# WEST VIRGINIA                      NaN                           NaN
# WEST_VIRGINIA               1470191.08                     825450.64
# WISCONSIN                   4762572.92                    2751990.64
# WYOMING                      572053.40                     354948.52
#
#                OTHER_EXPENDITURE  ...    GRADES_4_G    GRADES_8_G  \
# STATE                             ...
# ALABAMA             4.613081e+05  ...   57640.53125   57618.21875
# ALASKA              5.982192e+04  ...    9861.93750    9503.46875
# ARIZONA             3.344099e+05  ...   70428.50000   67289.68750
# ARKANSAS            2.537191e+05  ...   35175.81250   35856.28125
# CALIFORNIA          2.907487e+06  ...  446638.68750  429496.78125
# ...                          ...  ...           ...           ...
# WASHINGTON          4.154238e+05  ...   75210.43750   74138.21875
# WEST VIRGINIA                NaN  ...   21735.93750   22799.65625
# WEST_VIRGINIA       1.760134e+05  ...           NaN           NaN
# WISCONSIN           3.625247e+05  ...   61357.46875   62573.84375
# WYOMING             3.542100e+04  ...    7162.12500    7262.65625
#
#                 GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  GRADES_ALL_G  \
# STATE
# ALABAMA         45269.15625     464653.65   2.133993e+05  7.392764e+05
# ALASKA           8435.40625      80658.50   3.961205e+04  1.275366e+05
# ARIZONA         59524.84375     632177.35   3.001561e+05  8.991210e+05
# ARKANSAS        29542.81250     288069.95   1.368237e+05  4.623697e+05
# CALIFORNIA     377818.93750    3783631.40   1.883045e+06  5.843987e+06
# ...                     ...           ...            ...           ...
# WASHINGTON      70990.21875     625748.60   3.246117e+05  9.789468e+05
# WEST VIRGINIA   20056.43750     168134.40   8.321148e+04  2.970217e+05
# WEST_VIRGINIA           NaN           NaN            NaN           NaN
# WISCONSIN       64291.00000     497802.35   2.780265e+05  8.545297e+05
# WYOMING          6479.78125      54758.00   2.774333e+04  9.343384e+04
#
#                AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# STATE
# ALABAMA              224.555447        263.888462           213.234616
# ALASKA               234.009817        280.397007           210.664251
# ARIZONA              229.067877        275.113006           209.992880
# ARKANSAS             229.967542        270.223956           214.858589
# CALIFORNIA           225.659625        269.355244           207.911547
# ...                         ...               ...                  ...
# WASHINGTON           240.664865        285.512779           221.609525
# WEST VIRGINIA               NaN               NaN                  NaN
# WEST_VIRGINIA        230.705222        269.787391           215.871312
# WISCONSIN            239.829190        285.757657           221.900004
# WYOMING              239.338224        283.323654           223.591668
#
#                AVG_READING_8_SCORE
# STATE
# ALABAMA                 264.081357
# ALASKA                  263.336985
# ARIZONA                 263.851362
# ARKANSAS                263.808900
# CALIFORNIA              261.902652
# ...                            ...
# WASHINGTON              265.289671
# WEST VIRGINIA                  NaN
# WEST_VIRGINIA           265.330294
# WISCONSIN               264.279562
# WYOMING                 263.802500
#
# [62 rows x 23 columns]

# %%
# make a list of duplicates that have spaces in its state name
list_of_dups = []
for i in np.unique(df[['STATE']]):
    if (' ' in i) == True:
        list_of_dups.append(i)
#print(list_of_dups)

# concat the duplicated(with space char in state name) states to form a new data frame dd
dd = pd.DataFrame()
for i in list_of_dups:
    dd = pd.concat([dd,df.loc[df['STATE']== i]])


# replace spaces with '_' in STATE and PKEY columns
for state in list_of_dups:
    #print(i.replace(' ','_'))
    dd = dd.replace(state , state.replace(' ','_'))
    for year in np.unique(dd['YEAR']):
        pkey = str(year)+'_'+state
        dd = dd.replace(pkey , pkey.replace(' ','_'))
       

dd = dd.set_index('PRIMARY_KEY')
dd = dd.sort_index()

# make list of duplicate primary keys which contains spaces
list_of_dups_pkey = []
for i in np.unique(df[['PRIMARY_KEY']]):
    if (' ' in i) == True:
        list_of_dups_pkey.append(i)

# set index to the primary_key
dfp = df.set_index('PRIMARY_KEY')
for pkey in list_of_dups_pkey:
    dfp.drop(pkey, inplace = True)

# sort by primary key index
dfp=dfp.sort_index()

# make a list of drop list for dd dataframe which has null columns entirely
cnames = list(df.columns)
droplist=[]
# start from the ENROLL column
for i in cnames[3:]:
    #print(i,dd[i].isnull().mean())
    # check if the column is null
    if dd[i].isnull().mean() ==1 :
       droplist.append(i) 

dd.drop(columns=droplist, inplace = True)
# to merge using union of keys use 'outer' keyword 
dm = pd.merge(dfp, dd,'outer', on=['PRIMARY_KEY','STATE','YEAR'])

# %% [markdown]
# ### Q2
# Toplam gelir (TOTAL_REVENUE) ve toplam harcama (TOTAL_EXPENDITURE) değişkenlerinde aykırı değer tespit ettiyseniz bu derste öğrendiğiniz teknikleri uygulayarak bu aykırı değerleri ortadan kaldırın ve bunu yaptıktan sonra hiçbir aykırı değer kalmadığını doğrulayın.

# %% [markdown]
# ### Q3
# Toplam gelir (TOTAL_REVENUE) değişkeninden, toplam harcama (TOTAL_EXPENDITURE) değerini çıkartarak bütçe açığı olarak düşünülebilecek bir değişken oluşturun (aykırı değerleri temezlemeden). Bu yeni değişkende de aykırı değerler yer almakta mı? Varsa bu aykırı değerleri de temizleyin.

# %% [markdown]
# ### Q4
# Yine toplam gelir (TOTAL_REVENUE) değişkeninden, toplam harcama(TOTAL_EXPENDITURE) değerini çıkartarak bütçe açığı olarak düşünülebilecek bir değişken oluşturun. Fakat bu sefer aykırı değerleri temezledikten sonra bu işlemi yapın. Bu yeni değişkende de aykırı değerler var mı? Varsa bunları da temizlemekte fayda var.

# %% [markdown]
# ### Q5
# Şimdi elimizde üçüncü ve ve dördüncü sorularda oluşturduğumuz iki farklı bütçe değişkeni var. Bu ikisi arasında fark görüyor musunuz?

# %% [markdown]
# ### Q6
# Bizim için bütçe açığı çok önemli bir değişken olsaydı aykırı değerleri temizlemek için hangi yöntem daha iyi olurdu. Üçüncü soruda uguladığınız yöntem mi yoksa dördüncü sorudaki yöntem mi?
